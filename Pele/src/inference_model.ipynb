# %%
import pandas as pd
import numpy as np
import os
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from collections import Counter

# %%
FEATURE_COLS = ['grid', 'qual_pos', 'q_rel_gap', 'age_at_race', 'driver_form', 'team_form', 'driver_experience', 'circuit_avg_pos']
IMPORTANCE_MAP = {
    'team_form': 0.450637, 'driver_form': 0.189334, 'qual_pos': 0.094745,
    'circuit_avg_pos': 0.061325, 'driver_experience': 0.060547,
    'grid': 0.051296, 'age_at_race': 0.046638, 'q_rel_gap': 0.045478
}

# %%
class AttentionLayer(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.attn = nn.Linear(hidden_dim, 1)
    def forward(self, x):
        weights = torch.softmax(self.attn(x), dim=1)
        return torch.sum(weights * x, dim=1)

# %%
class F1UltimateHybridModel(nn.Module):
    def __init__(self, num_features, d_model=128, nhead=8):
        super().__init__()
        
        self.embedding = nn.Linear(num_features, d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, batch_first=True)
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)
        
        
        self.lstm = nn.LSTM(d_model, d_model, batch_first=True, bidirectional=True)
        
        
        self.attention = AttentionLayer(d_model * 2)
        
        
        self.fc = nn.Sequential(
            nn.Linear(d_model * 2, 64), 
            nn.GELU(),
            nn.LayerNorm(64),           
            nn.Linear(64, 1),           
            nn.Sigmoid()                
        )

    def forward(self, x):
        x = self.embedding(x)
        x = self.transformer(x)
        lstm_out, _ = self.lstm(x)
        context = self.attention(lstm_out)
        return self.fc(context)

# %%
def get_main_points(pos):
    pts = {1: 25, 2: 18, 3: 15, 4: 12, 5: 10, 6: 8, 7: 6, 8: 4, 9: 2, 10: 1}
    return pts.get(int(pos), 0)

# %%
def get_sprint_points(pos):
    pts = {1: 8, 2: 7, 3: 6, 4: 5, 5: 4, 6: 3, 7: 2, 8: 1}
    return pts.get(int(pos), 0)

# %%
def run_ultimate_simulation():
    data_dir = '../data'
    data_engineered_dir = '../data_engineered'
    model_path = '../models/f1_ultimate_hybrid.pth'
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    sim_df = pd.read_csv(os.path.join(data_engineered_dir, 'historical_sim_ready_v2.csv'), low_memory=False)
    results_df = pd.read_csv(os.path.join(data_dir, 'results.csv'))
    drivers_df = pd.read_csv(os.path.join(data_dir, 'drivers.csv'), encoding='ISO-8859-1')
    constructors_df = pd.read_csv(os.path.join(data_dir, 'constructors.csv'), encoding='ISO-8859-1')
    races_df = pd.read_csv(os.path.join(data_dir, 'races.csv'))

    scaler = StandardScaler()
    sim_df[FEATURE_COLS] = scaler.fit_transform(sim_df[FEATURE_COLS])
    for col in FEATURE_COLS:
        sim_df[col] = sim_df[col] * (1.0 + IMPORTANCE_MAP.get(col, 0.0))

    results_df = pd.merge(results_df, races_df[['raceId', 'year']], on='raceId', how='left')
    results_df['actual_main_pts'] = results_df['positionOrder'].apply(get_main_points)
    
    actual_driver_main = results_df.groupby(['year', 'driverId'])['actual_main_pts'].sum().reset_index()
    actual_driver_main['driver_name'] = actual_driver_main['driverId'].map(drivers_df.set_index('driverId')['forename'] + " " + drivers_df.set_index('driverId')['surname'])
    actual_driver_main['original_rank'] = actual_driver_main.groupby('year')['actual_main_pts'].rank(method='first', ascending=False)

    model = F1UltimateHybridModel(len(FEATURE_COLS)).to(device)
    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path, map_location=device))
        model.eval()
        print(f"--- v3 Ultimate Hybrid load success (Device: {device}) ---")
    else:
        print("Model file not found.")
        return

    const_id_lookup = results_df.drop_duplicates(['raceId', 'driverId']).set_index(['raceId', 'driverId'])['constructorId'].to_dict()
    sim_df['constructorId'] = sim_df.apply(lambda x: const_id_lookup.get((int(x['raceId']), int(x['driverId'])), 0), axis=1)

    sprint_results = []
    SEQ_LEN = 3
    for driver_id, group in sim_df.groupby('driverId'):
        group = group.sort_values(['year', 'round'])
        if len(group) <= SEQ_LEN: continue
        f_vals = group[FEATURE_COLS].values
        for i in range(len(group) - SEQ_LEN):
            target_row = group.iloc[i + SEQ_LEN]
            if 1 <= int(target_row['round']) <= 6:
                seq_x = torch.FloatTensor(f_vals[i:i+SEQ_LEN]).unsqueeze(0).to(device)
                with torch.no_grad():
                    pred_score = model(seq_x).item()
                sprint_results.append({
                    'year': int(target_row['year']), 'round': int(target_row['round']),
                    'driverId': int(driver_id), 'constructorId': int(target_row['constructorId']),
                    'pred_score': pred_score
                })

    sprint_df = pd.DataFrame(sprint_results).drop_duplicates(['year', 'round', 'driverId'])
    sprint_df['pred_pos'] = sprint_df.groupby(['year', 'round'])['pred_score'].rank(method='first', ascending=True)
    sprint_df['sprint_pts'] = sprint_df['pred_pos'].apply(get_sprint_points)
    driver_sprint_sum = sprint_df.groupby(['year', 'driverId'])['sprint_pts'].sum().reset_index()

    final_comparison = pd.merge(actual_driver_main, driver_sprint_sum, on=['year', 'driverId'], how='left').fillna(0)
    final_comparison['total_pts'] = final_comparison['actual_main_pts'] + final_comparison['sprint_pts']
    final_comparison['new_rank'] = final_comparison.groupby('year')['total_pts'].rank(method='first', ascending=False)

    history_winners = []
    rank_flips = []

    for yr in sorted(final_comparison['year'].unique(), reverse=True):
        orig_winner = final_comparison[(final_comparison['year'] == yr) & (final_comparison['original_rank'] == 1)].iloc[0]
        new_winner = final_comparison[(final_comparison['year'] == yr) & (final_comparison['new_rank'] == 1)].iloc[0]
        history_winners.append(new_winner['driver_name'])

        print(f"\n" + "="*70)
        print(f" 🏁 {yr} SEASON ANALYSIS")
        print(f" - Actual Champion: {orig_winner['driver_name']}")
        
        if orig_winner['driverId'] != new_winner['driverId']:
            print(f" 🚨 [RANK FLIPPED!] -> New Champion: {new_winner['driver_name']}")
            rank_flips.append({'year': yr, 'from': orig_winner['driver_name'], 'to': new_winner['driver_name']})
        else:
            print(f" ✅ [CHAMPION RETAINED] : {new_winner['driver_name']}")
        print(f" - Points: {int(new_winner['total_pts'])} (Sprint contribution: +{int(new_winner['sprint_pts'])})")

    print("\n\n" + "#"*70)
    print(" 📊 FINAL SUMMARY: THE MOST DOMINANT IN AI-HYBRID ERA ")
    print("#"*70)
    
    print(f"\n[Years with Championship Flips]")
    for f in rank_flips:
        print(f"🚩 {f['year']}: {f['from']} ➔ {f['to']} (Title Changed by AI Sprint)")

    winner_counts = Counter(history_winners).most_common()
    print(f"\n[Most Driver Titles]")
    for name, count in winner_counts:
        print(f"- {name:<25} : {count} titles")
    print("#"*70)

# %%
if __name__ == "__main__":
    run_ultimate_simulation()
# Out:
# --- v3 Ultimate Hybrid load success (Device: cuda) ---
#
# ======================================================================
#  🏁 2024 SEASON ANALYSIS
#  - Actual Champion: Max Verstappen
#  ✅ [CHAMPION RETAINED] : Max Verstappen
#  - Points: 396 (Sprint contribution: +0)
#
# ======================================================================
#  🏁 2023 SEASON ANALYSIS
#  - Actual Champion: Max Verstappen
#  ✅ [CHAMPION RETAINED] : Max Verstappen
#  - Points: 521 (Sprint contribution: +0)
#
# ======================================================================
#  🏁 2022 SEASON ANALYSIS
#  - Actual Champion: Max Verstappen
#  ✅ [CHAMPION RETAINED] : Max Verstappen
#  - Points: 428 (Sprint contribution: +0)
#
# ======================================================================
#  🏁 2021 SEASON ANALYSIS
#  - Actual Champion: Max Verstappen
#  ✅ [CHAMPION RETAINED] : Max Verstappen
#  - Points: 396 (Sprint contribution: +0)
#
# ======================================================================
#  🏁 2020 SEASON ANALYSIS
#  - Actual Champion: Lewis Hamilton
#  ✅ [CHAMPION RETAINED] : Lewis Hamilton
#  - Points: 384 (Sprint contribution: +43)
#
# ======================================================================
#  🏁 2019 SEASON ANALYSIS
#  - Actual Champion: Lewis Hamilton
#  ✅ [CHAMPION RETAINED] : Lewis Hamilton
#  - Points: 453 (Sprint contribution: +46)
#
# ======================================================================
#  🏁 2018 SEASON ANALYSIS
#  - Actual Champion: Lewis Hamilton
#  ✅ [CHAMPION RETAINED] : Lewis Hamilton
#  - Points: 449 (Sprint contribution: +41)
#
# ======================================================================
#  🏁 2017 SEASON ANALYSIS
#  - Actual Champion: Lewis Hamilton
#  ✅ [CHAMPION RETAINED] : Lewis Hamilton
#  - Points: 411 (Sprint contribution: +48)
#
# ======================================================================
#  🏁 2016 SEASON ANALYSIS
#  - Actual Champion: Nico Rosberg
#  ✅ [CHAMPION RETAINED] : Nico Rosberg
#  - Points: 428 (Sprint contribution: +43)
#
# ======================================================================
#  🏁 2015 SEASON ANALYSIS
#  - Actual Champion: Lewis Hamilton
#  ✅ [CHAMPION RETAINED] : Lewis Hamilton
#  - Points: 429 (Sprint contribution: +48)
#
# ======================================================================
#  🏁 2014 SEASON ANALYSIS
#  - Actual Champion: Lewis Hamilton
#  ✅ [CHAMPION RETAINED] : Lewis Hamilton
#  - Points: 367 (Sprint contribution: +8)
#
# ======================================================================
#  🏁 2013 SEASON ANALYSIS
#  - Actual Champion: Sebastian Vettel
#  ✅ [CHAMPION RETAINED] : Sebastian Vettel
#  - Points: 442 (Sprint contribution: +45)
#
# ======================================================================
#  🏁 2012 SEASON ANALYSIS
#  - Actual Champion: Sebastian Vettel
#  ✅ [CHAMPION RETAINED] : Sebastian Vettel
#  - Points: 324 (Sprint contribution: +43)
#
# ======================================================================
#  🏁 2011 SEASON ANALYSIS
#  - Actual Champion: Sebastian Vettel
#  ✅ [CHAMPION RETAINED] : Sebastian Vettel
#  - Points: 432 (Sprint contribution: +40)
#
# ======================================================================
#  🏁 2010 SEASON ANALYSIS
#  - Actual Champion: Sebastian Vettel
#  🚨 [RANK FLIPPED!] -> New Champion: Lewis Hamilton
#  - Points: 281 (Sprint contribution: +41)
#
# ======================================================================
#  🏁 2009 SEASON ANALYSIS
#  - Actual Champion: Jenson Button
#  ✅ [CHAMPION RETAINED] : Jenson Button
#  - Points: 268 (Sprint contribution: +16)
#
# ======================================================================
#  🏁 2008 SEASON ANALYSIS
#  - Actual Champion: Lewis Hamilton
#  ✅ [CHAMPION RETAINED] : Lewis Hamilton
#  - Points: 277 (Sprint contribution: +34)
#
# ======================================================================
#  🏁 2007 SEASON ANALYSIS
#  - Actual Champion: Kimi RÃ¤ikkÃ¶nen
#  🚨 [RANK FLIPPED!] -> New Champion: Fernando Alonso
#  - Points: 304 (Sprint contribution: +38)
#
# ======================================================================
#  🏁 2006 SEASON ANALYSIS
#  - Actual Champion: Fernando Alonso
#  ✅ [CHAMPION RETAINED] : Fernando Alonso
#  - Points: 362 (Sprint contribution: +41)
#
# ======================================================================
#  🏁 2005 SEASON ANALYSIS
#  - Actual Champion: Fernando Alonso
#  ✅ [CHAMPION RETAINED] : Fernando Alonso
#  - Points: 356 (Sprint contribution: +34)
#
# ======================================================================
#  🏁 2004 SEASON ANALYSIS
#  - Actual Champion: Michael Schumacher
#  ✅ [CHAMPION RETAINED] : Michael Schumacher
#  - Points: 402 (Sprint contribution: +35)
#
# ======================================================================
#  🏁 2003 SEASON ANALYSIS
#  - Actual Champion: Michael Schumacher
#  ✅ [CHAMPION RETAINED] : Michael Schumacher
#  - Points: 279 (Sprint contribution: +43)
#
# ======================================================================
#  🏁 2002 SEASON ANALYSIS
#  - Actual Champion: Michael Schumacher
#  ✅ [CHAMPION RETAINED] : Michael Schumacher
#  - Points: 427 (Sprint contribution: +47)
#
# ======================================================================
#  🏁 2001 SEASON ANALYSIS
#  - Actual Champion: Michael Schumacher
#  ✅ [CHAMPION RETAINED] : Michael Schumacher
#  - Points: 374 (Sprint contribution: +47)
#
# ======================================================================
#  🏁 2000 SEASON ANALYSIS
#  - Actual Champion: Michael Schumacher
#  ✅ [CHAMPION RETAINED] : Michael Schumacher
#  - Points: 320 (Sprint contribution: +34)
#
# ======================================================================
#  🏁 1999 SEASON ANALYSIS
#  - Actual Champion: Eddie Irvine
#  ✅ [CHAMPION RETAINED] : Eddie Irvine
#  - Points: 266 (Sprint contribution: +29)
#
# ======================================================================
#  🏁 1998 SEASON ANALYSIS
#  - Actual Champion: Mika HÃ¤kkinen
#  ✅ [CHAMPION RETAINED] : Mika HÃ¤kkinen
#  - Points: 294 (Sprint contribution: +23)
#
# ======================================================================
#  🏁 1997 SEASON ANALYSIS
#  - Actual Champion: Michael Schumacher
#  ✅ [CHAMPION RETAINED] : Michael Schumacher
#  - Points: 270 (Sprint contribution: +41)
#
# ======================================================================
#  🏁 1996 SEASON ANALYSIS
#  - Actual Champion: Damon Hill
#  ✅ [CHAMPION RETAINED] : Damon Hill
#  - Points: 279 (Sprint contribution: +21)
#
# ======================================================================
#  🏁 1995 SEASON ANALYSIS
#  - Actual Champion: Michael Schumacher
#  ✅ [CHAMPION RETAINED] : Michael Schumacher
#  - Points: 303 (Sprint contribution: +35)
#
# ======================================================================
#  🏁 1994 SEASON ANALYSIS
#  - Actual Champion: Damon Hill
#  ✅ [CHAMPION RETAINED] : Damon Hill
#  - Points: 283 (Sprint contribution: +31)
#
# ======================================================================
#  🏁 1993 SEASON ANALYSIS
#  - Actual Champion: Alain Prost
#  ✅ [CHAMPION RETAINED] : Alain Prost
#  - Points: 294 (Sprint contribution: +23)
#
# ======================================================================
#  🏁 1992 SEASON ANALYSIS
#  - Actual Champion: Nigel Mansell
#  ✅ [CHAMPION RETAINED] : Nigel Mansell
#  - Points: 317 (Sprint contribution: +38)
#
# ======================================================================
#  🏁 1991 SEASON ANALYSIS
#  - Actual Champion: Ayrton Senna
#  ✅ [CHAMPION RETAINED] : Ayrton Senna
#  - Points: 328 (Sprint contribution: +41)
#
# ======================================================================
#  🏁 1990 SEASON ANALYSIS
#  - Actual Champion: Ayrton Senna
#  ✅ [CHAMPION RETAINED] : Ayrton Senna
#  - Points: 256 (Sprint contribution: +25)
#
# ======================================================================
#  🏁 1989 SEASON ANALYSIS
#  - Actual Champion: Alain Prost
#  ✅ [CHAMPION RETAINED] : Alain Prost
#  - Points: 293 (Sprint contribution: +48)
#
# ======================================================================
#  🏁 1988 SEASON ANALYSIS
#  - Actual Champion: Alain Prost
#  ✅ [CHAMPION RETAINED] : Alain Prost
#  - Points: 332 (Sprint contribution: +31)
#
# ======================================================================
#  🏁 1987 SEASON ANALYSIS
#  - Actual Champion: Nelson Piquet
#  ✅ [CHAMPION RETAINED] : Nelson Piquet
#  - Points: 262 (Sprint contribution: +34)
#
# ======================================================================
#  🏁 1986 SEASON ANALYSIS
#  - Actual Champion: Alain Prost
#  ✅ [CHAMPION RETAINED] : Alain Prost
#  - Points: 270 (Sprint contribution: +37)
#
# ======================================================================
#  🏁 1985 SEASON ANALYSIS
#  - Actual Champion: Alain Prost
#  ✅ [CHAMPION RETAINED] : Alain Prost
#  - Points: 278 (Sprint contribution: +45)
#
# ======================================================================
#  🏁 1984 SEASON ANALYSIS
#  - Actual Champion: Alain Prost
#  ✅ [CHAMPION RETAINED] : Alain Prost
#  - Points: 266 (Sprint contribution: +39)
#
# ======================================================================
#  🏁 1983 SEASON ANALYSIS
#  - Actual Champion: Alain Prost
#  🚨 [RANK FLIPPED!] -> New Champion: Nelson Piquet
#  - Points: 199 (Sprint contribution: +16)
#
# ======================================================================
#  🏁 1982 SEASON ANALYSIS
#  - Actual Champion: Keke Rosberg
#  🚨 [RANK FLIPPED!] -> New Champion: Alain Prost
#  - Points: 155 (Sprint contribution: +39)
#
# ======================================================================
#  🏁 1981 SEASON ANALYSIS
#  - Actual Champion: Nelson Piquet
#  🚨 [RANK FLIPPED!] -> New Champion: Carlos Reutemann
#  - Points: 202 (Sprint contribution: +40)
#
# ======================================================================
#  🏁 1980 SEASON ANALYSIS
#  - Actual Champion: Alan Jones
#  ✅ [CHAMPION RETAINED] : Alan Jones
#  - Points: 249 (Sprint contribution: +40)
#
# ======================================================================
#  🏁 1979 SEASON ANALYSIS
#  - Actual Champion: Jody Scheckter
#  ✅ [CHAMPION RETAINED] : Jody Scheckter
#  - Points: 213 (Sprint contribution: +11)
#
# ======================================================================
#  🏁 1978 SEASON ANALYSIS
#  - Actual Champion: Mario Andretti
#  ✅ [CHAMPION RETAINED] : Mario Andretti
#  - Points: 195 (Sprint contribution: +0)
#
# ======================================================================
#  🏁 1977 SEASON ANALYSIS
#  - Actual Champion: Niki Lauda
#  ✅ [CHAMPION RETAINED] : Niki Lauda
#  - Points: 254 (Sprint contribution: +34)
#
# ======================================================================
#  🏁 1976 SEASON ANALYSIS
#  - Actual Champion: Niki Lauda
#  ✅ [CHAMPION RETAINED] : Niki Lauda
#  - Points: 243 (Sprint contribution: +36)
#
# ======================================================================
#  🏁 1975 SEASON ANALYSIS
#  - Actual Champion: Niki Lauda
#  ✅ [CHAMPION RETAINED] : Niki Lauda
#  - Points: 213 (Sprint contribution: +0)
#
# ======================================================================
#  🏁 1974 SEASON ANALYSIS
#  - Actual Champion: Emerson Fittipaldi
#  ✅ [CHAMPION RETAINED] : Emerson Fittipaldi
#  - Points: 217 (Sprint contribution: +35)
#
# ======================================================================
#  🏁 1973 SEASON ANALYSIS
#  - Actual Champion: Jackie Stewart
#  ✅ [CHAMPION RETAINED] : Jackie Stewart
#  - Points: 250 (Sprint contribution: +29)
#
# ======================================================================
#  🏁 1972 SEASON ANALYSIS
#  - Actual Champion: Emerson Fittipaldi
#  ✅ [CHAMPION RETAINED] : Emerson Fittipaldi
#  - Points: 192 (Sprint contribution: +16)
#
# ======================================================================
#  🏁 1971 SEASON ANALYSIS
#  - Actual Champion: Jackie Stewart
#  ✅ [CHAMPION RETAINED] : Jackie Stewart
#  - Points: 188 (Sprint contribution: +10)
#
# ======================================================================
#  🏁 1970 SEASON ANALYSIS
#  - Actual Champion: Jochen Rindt
#  🚨 [RANK FLIPPED!] -> New Champion: Jacky Ickx
#  - Points: 157 (Sprint contribution: +33)
#
# ======================================================================
#  🏁 1969 SEASON ANALYSIS
#  - Actual Champion: Jackie Stewart
#  ✅ [CHAMPION RETAINED] : Jackie Stewart
#  - Points: 213 (Sprint contribution: +31)
#
# ======================================================================
#  🏁 1968 SEASON ANALYSIS
#  - Actual Champion: Graham Hill
#  🚨 [RANK FLIPPED!] -> New Champion: Denny Hulme
#  - Points: 167 (Sprint contribution: +46)
#
# ======================================================================
#  🏁 1967 SEASON ANALYSIS
#  - Actual Champion: Denny Hulme
#  ✅ [CHAMPION RETAINED] : Denny Hulme
#  - Points: 184 (Sprint contribution: +23)
#
# ======================================================================
#  🏁 1966 SEASON ANALYSIS
#  - Actual Champion: Jack Brabham
#  ✅ [CHAMPION RETAINED] : Jack Brabham
#  - Points: 130 (Sprint contribution: +0)
#
# ======================================================================
#  🏁 1965 SEASON ANALYSIS
#  - Actual Champion: Graham Hill
#  ✅ [CHAMPION RETAINED] : Graham Hill
#  - Points: 171 (Sprint contribution: +18)
#
# ======================================================================
#  🏁 1964 SEASON ANALYSIS
#  - Actual Champion: Graham Hill
#  ✅ [CHAMPION RETAINED] : Graham Hill
#  - Points: 158 (Sprint contribution: +32)
#
# ======================================================================
#  🏁 1963 SEASON ANALYSIS
#  - Actual Champion: Jim Clark
#  ✅ [CHAMPION RETAINED] : Jim Clark
#  - Points: 232 (Sprint contribution: +20)
#
# ======================================================================
#  🏁 1962 SEASON ANALYSIS
#  - Actual Champion: Graham Hill
#  ✅ [CHAMPION RETAINED] : Graham Hill
#  - Points: 158 (Sprint contribution: +0)
#
# ======================================================================
#  🏁 1961 SEASON ANALYSIS
#  - Actual Champion: Phil Hill
#  ✅ [CHAMPION RETAINED] : Phil Hill
#  - Points: 128 (Sprint contribution: +10)
#
# ======================================================================
#  🏁 1960 SEASON ANALYSIS
#  - Actual Champion: Jack Brabham
#  🚨 [RANK FLIPPED!] -> New Champion: Bruce McLaren
#  - Points: 158 (Sprint contribution: +37)
#
# ======================================================================
#  🏁 1959 SEASON ANALYSIS
#  - Actual Champion: Jack Brabham
#  ✅ [CHAMPION RETAINED] : Jack Brabham
#  - Points: 124 (Sprint contribution: +14)
#
# ======================================================================
#  🏁 1958 SEASON ANALYSIS
#  - Actual Champion: Mike Hawthorn
#  ✅ [CHAMPION RETAINED] : Mike Hawthorn
#  - Points: 173 (Sprint contribution: +33)
#
# ======================================================================
#  🏁 1957 SEASON ANALYSIS
#  - Actual Champion: Juan Fangio
#  ✅ [CHAMPION RETAINED] : Juan Fangio
#  - Points: 154 (Sprint contribution: +18)
#
# ======================================================================
#  🏁 1956 SEASON ANALYSIS
#  - Actual Champion: Juan Fangio
#  ✅ [CHAMPION RETAINED] : Juan Fangio
#  - Points: 162 (Sprint contribution: +21)
#
# ======================================================================
#  🏁 1955 SEASON ANALYSIS
#  - Actual Champion: Juan Fangio
#  ✅ [CHAMPION RETAINED] : Juan Fangio
#  - Points: 137 (Sprint contribution: +19)
#
# ======================================================================
#  🏁 1954 SEASON ANALYSIS
#  - Actual Champion: Juan Fangio
#  ✅ [CHAMPION RETAINED] : Juan Fangio
#  - Points: 205 (Sprint contribution: +28)
#
# ======================================================================
#  🏁 1953 SEASON ANALYSIS
#  - Actual Champion: Alberto Ascari
#  ✅ [CHAMPION RETAINED] : Alberto Ascari
#  - Points: 181 (Sprint contribution: +40)
#
# ======================================================================
#  🏁 1952 SEASON ANALYSIS
#  - Actual Champion: Alberto Ascari
#  ✅ [CHAMPION RETAINED] : Alberto Ascari
#  - Points: 190 (Sprint contribution: +40)
#
# ======================================================================
#  🏁 1951 SEASON ANALYSIS
#  - Actual Champion: Juan Fangio
#  🚨 [RANK FLIPPED!] -> New Champion: Alberto Ascari
#  - Points: 142 (Sprint contribution: +36)
#
# ======================================================================
#  🏁 1950 SEASON ANALYSIS
#  - Actual Champion: Nino Farina
#  ✅ [CHAMPION RETAINED] : Nino Farina
#  - Points: 109 (Sprint contribution: +16)
#
#
# ######################################################################
#  📊 FINAL SUMMARY: THE MOST DOMINANT IN AI-HYBRID ERA
# ######################################################################
#
# [Years with Championship Flips]
# 🚩 2010: Sebastian Vettel ➔ Lewis Hamilton (Title Changed by AI Sprint)
# 🚩 2007: Kimi RÃ¤ikkÃ¶nen ➔ Fernando Alonso (Title Changed by AI Sprint)
# 🚩 1983: Alain Prost ➔ Nelson Piquet (Title Changed by AI Sprint)
# 🚩 1982: Keke Rosberg ➔ Alain Prost (Title Changed by AI Sprint)
# 🚩 1981: Nelson Piquet ➔ Carlos Reutemann (Title Changed by AI Sprint)
# 🚩 1970: Jochen Rindt ➔ Jacky Ickx (Title Changed by AI Sprint)
# 🚩 1968: Graham Hill ➔ Denny Hulme (Title Changed by AI Sprint)
# 🚩 1960: Jack Brabham ➔ Bruce McLaren (Title Changed by AI Sprint)
# 🚩 1951: Juan Fangio ➔ Alberto Ascari (Title Changed by AI Sprint)
#
# [Most Driver Titles]
# - Lewis Hamilton            : 8 titles
# - Michael Schumacher        : 7 titles
# - Alain Prost               : 7 titles
# - Max Verstappen            : 4 titles
# - Juan Fangio               : 4 titles
# - Sebastian Vettel          : 3 titles
# - Fernando Alonso           : 3 titles
# - Niki Lauda                : 3 titles
# - Jackie Stewart            : 3 titles
# - Graham Hill               : 3 titles
# - Alberto Ascari            : 3 titles
# - Damon Hill                : 2 titles
# - Ayrton Senna              : 2 titles
# - Nelson Piquet             : 2 titles
# - Emerson Fittipaldi        : 2 titles
# - Denny Hulme               : 2 titles
# - Jack Brabham              : 2 titles
# - Nico Rosberg              : 1 titles
# - Jenson Button             : 1 titles
# - Eddie Irvine              : 1 titles
# - Mika HÃ¤kkinen            : 1 titles
# - Nigel Mansell             : 1 titles
# - Carlos Reutemann          : 1 titles
# - Alan Jones                : 1 titles
# - Jody Scheckter            : 1 titles
# - Mario Andretti            : 1 titles
# - Jacky Ickx                : 1 titles
# - Jim Clark                 : 1 titles
# - Phil Hill                 : 1 titles
# - Bruce McLaren             : 1 titles
# - Mike Hawthorn             : 1 titles
# - Nino Farina               : 1 titles
# ######################################################################
